# %%
# !source .venv/bin/activate

# %%
# !python mineru_pipeline_all.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/workspace/AISumerCamp_multiModal_RAG/mineru_pipeline_all.py", line 198, in <module>
#     main()
#   File "/mnt/workspace/AISumerCamp_multiModal_RAG/mineru_pipeline_all.py", line 190, in main
#     parse_all_pdfs(datas_dir, content_dir)
#   File "/mnt/workspace/AISumerCamp_multiModal_RAG/mineru_pipeline_all.py", line 13, in parse_all_pdfs
#     from mineru_parse_pdf import do_parse
#   File "/mnt/workspace/AISumerCamp_multiModal_RAG/mineru_parse_pdf.py", line 8, in <module>
#     from loguru import logger
# ModuleNotFoundError: No module named 'loguru'
